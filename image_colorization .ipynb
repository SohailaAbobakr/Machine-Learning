# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import matplotlib.image as mpimg
from PIL import Image
import tensorflow as tf
import numpy as np
from matplotlib import image
from tensorflow import keras
from tensorflow.keras import layers
from skimage.color import rgb2lab, lab2rgb
from keras.layers import Conv2D, UpSampling2D
from keras.models import Sequential

# %%
import zipfile 
zip_ref = zipfile.ZipFile('/content/other.zip')
zip_ref.extractall('/content')
zip_ref.close()

# %%
ImagePath='/content/other'

# %%
from sklearn.model_selection import train_test_split

# Size of the image required to train our model
img_size = 256

# These many images will be used from the data archive
dataset_split = 1200


x = []
y = []
for image_file in os.listdir( ImagePath )[ 0 : dataset_split ]:
    rgb_image = Image.open( os.path.join( ImagePath , image_file ) ).resize( ( img_size , img_size ) )
    # Normalize the RGB image array
    rgb_img_array = (np.asarray( rgb_image ) ) / 255
    gray_image = rgb_image.convert( 'L' )
    # Normalize the grayscale image array
    gray_img_array = ( np.asarray( gray_image ).reshape( ( img_size , img_size , 1 ) ) ) / 255
    # Append both the image arrays
    x.append( gray_img_array )
    y.append( rgb_img_array )

# Train-test splitting
X_train, X_test, y_train, y_test = train_test_split( np.array(x) , np.array(y) , test_size=0.1 )

# %%
X = np.array(x)
Y = np.array(y)
print(np.shape(X))
print(np.shape(Y))
# Out:
# (1200, 256, 256, 1)
# (1200, 256, 256, 3)

# %%
print(np.shape(X_train))
print(np.shape(y_train))
print(np.shape(X_test))
print(np.shape(y_test))
# Out:
# (1080, 256, 256, 1)
# (1080, 256, 256, 3)
# (120, 256, 256, 1)
# (120, 256, 256, 3)

# %%
import keras
from keras import layers


input_img =keras.Input(shape=(X.shape[1:]))

#256
x = layers.Conv2D(32, (5, 5), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

#128
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

#64

x = layers.Conv2D(3, (3, 3), activation='relu', padding='same')(x)
encoded = x


x = layers.Conv2DTranspose(32, (3, 3), strides=(2,2), activation='relu', padding='same')(encoded)
#128

x = layers.Conv2DTranspose(32, (5, 5), strides=(2,2), activation='relu', padding='same')(x)
#256


x= layers.Conv2D(3, (3, 3), activation='relu', padding='same')(x)
decoded = x

model = keras.Model(input_img, decoded)
model.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 1)]     0
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 32)      832
#
#  max_pooling2d_2 (MaxPooling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 32)      9248
#
#  max_pooling2d_3 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 3)         867
#
#  conv2d_transpose_2 (Conv2DT  (None, 128, 128, 32)     896
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 256, 256, 32)     25632
#  ranspose)
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 3)       867
#
# =================================================================
# Total params: 38,342
# Trainable params: 38,342
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(np.shape(X))
print(np.shape(Y))
# Out:
# (1200, 256, 256, 1)
# (1200, 256, 256, 3)

# %%
model.fit(X, Y,
                epochs=100,
                batch_size=128,
                shuffle=True,
                )
# Out:
# Epoch 1/100
# 10/10 [==============================] - 6s 538ms/step - loss: 0.0177 - accuracy: 0.5596
# Epoch 2/100
# 10/10 [==============================] - 5s 543ms/step - loss: 0.0175 - accuracy: 0.5732
# Epoch 3/100
# 10/10 [==============================] - 5s 544ms/step - loss: 0.0174 - accuracy: 0.5748
# Epoch 4/100
# 10/10 [==============================] - 6s 550ms/step - loss: 0.0173 - accuracy: 0.5425
# Epoch 5/100
# 10/10 [==============================] - 5s 544ms/step - loss: 0.0171 - accuracy: 0.5764
# Epoch 6/100
# 10/10 [==============================] - 6s 551ms/step - loss: 0.0171 - accuracy: 0.5324
# Epoch 7/100
# 10/10 [==============================] - 6s 551ms/step - loss: 0.0170 - accuracy: 0.5742
# Epoch 8/100
# 10/10 [==============================] - 6s 551ms/step - loss: 0.0168 - accuracy: 0.5489
# Epoch 9/100
# 10/10 [==============================] - 6s 548ms/step - loss: 0.0167 - accuracy: 0.5541
# Epoch 10/100
# 10/10 [==============================] - 6s 550ms/step - loss: 0.0167 - accuracy: 0.5668
# Epoch 11/100
# 10/10 [==============================] - 6s 552ms/step - loss: 0.0166 - accuracy: 0.5676
# Epoch 12/100
# 10/10 [==============================] - 6s 554ms/step - loss: 0.0164 - accuracy: 0.5591
# Epoch 13/100
# 10/10 [==============================] - 6s 558ms/step - loss: 0.0165 - accuracy: 0.5461
# Epoch 14/100
# 10/10 [==============================] - 6s 554ms/step - loss: 0.0163 - accuracy: 0.5648
# Epoch 15/100
# 10/10 [==============================] - 6s 559ms/step - loss: 0.0164 - accuracy: 0.5475
# Epoch 16/100
# 10/10 [==============================] - 6s 561ms/step - loss: 0.0168 - accuracy: 0.5635
# Epoch 17/100
# 10/10 [==============================] - 6s 562ms/step - loss: 0.0164 - accuracy: 0.5404
# Epoch 18/100
# 10/10 [==============================] - 6s 562ms/step - loss: 0.0163 - accuracy: 0.5441
# Epoch 19/100
# 10/10 [==============================] - 6s 559ms/step - loss: 0.0163 - accuracy: 0.5462
# Epoch 20/100
# 10/10 [==============================] - 6s 558ms/step - loss: 0.0161 - accuracy: 0.5447
# Epoch 21/100
# 10/10 [==============================] - 6s 560ms/step - loss: 0.0161 - accuracy: 0.5498
# Epoch 22/100
# 10/10 [==============================] - 6s 567ms/step - loss: 0.0160 - accuracy: 0.5536
# Epoch 23/100
# 10/10 [==============================] - 6s 564ms/step - loss: 0.0159 - accuracy: 0.5474
# Epoch 24/100
# 10/10 [==============================] - 6s 567ms/step - loss: 0.0159 - accuracy: 0.5520
# Epoch 25/100
# 10/10 [==============================] - 6s 564ms/step - loss: 0.0160 - accuracy: 0.5308
# Epoch 26/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0159 - accuracy: 0.5334
# Epoch 27/100
# 10/10 [==============================] - 6s 561ms/step - loss: 0.0159 - accuracy: 0.5501
# Epoch 28/100
# 10/10 [==============================] - 6s 565ms/step - loss: 0.0158 - accuracy: 0.5474
# Epoch 29/100
# 10/10 [==============================] - 6s 566ms/step - loss: 0.0157 - accuracy: 0.5392
# Epoch 30/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0156 - accuracy: 0.5249
# Epoch 31/100
# 10/10 [==============================] - 6s 567ms/step - loss: 0.0156 - accuracy: 0.5512
# Epoch 32/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0156 - accuracy: 0.5348
# Epoch 33/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0157 - accuracy: 0.5363
# Epoch 34/100
# 10/10 [==============================] - 6s 573ms/step - loss: 0.0156 - accuracy: 0.5324
# Epoch 35/100
# 10/10 [==============================] - 6s 565ms/step - loss: 0.0155 - accuracy: 0.5462
# Epoch 36/100
# 10/10 [==============================] - 6s 570ms/step - loss: 0.0154 - accuracy: 0.5402
# Epoch 37/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0155 - accuracy: 0.5397
# Epoch 38/100
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0156 - accuracy: 0.5078
# Epoch 39/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0156 - accuracy: 0.5468
# Epoch 40/100
# 10/10 [==============================] - 6s 572ms/step - loss: 0.0155 - accuracy: 0.5293
# Epoch 41/100
# 10/10 [==============================] - 6s 572ms/step - loss: 0.0154 - accuracy: 0.5453
# Epoch 42/100
# 10/10 [==============================] - 6s 570ms/step - loss: 0.0155 - accuracy: 0.5444
# Epoch 43/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0156 - accuracy: 0.5369
# Epoch 44/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0156 - accuracy: 0.5460
# Epoch 45/100
# 10/10 [==============================] - 6s 572ms/step - loss: 0.0156 - accuracy: 0.5453
# Epoch 46/100
# 10/10 [==============================] - 6s 569ms/step - loss: 0.0155 - accuracy: 0.5461
# Epoch 47/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.0155 - accuracy: 0.5306
# Epoch 48/100
# 10/10 [==============================] - 6s 564ms/step - loss: 0.0153 - accuracy: 0.5431
# Epoch 49/100
# 10/10 [==============================] - 6s 580ms/step - loss: 0.0154 - accuracy: 0.5391
# Epoch 50/100
# 10/10 [==============================] - 6s 579ms/step - loss: 0.0152 - accuracy: 0.5305
# Epoch 51/100
# 10/10 [==============================] - 6s 588ms/step - loss: 0.0153 - accuracy: 0.5456
# Epoch 52/100
# 10/10 [==============================] - 6s 573ms/step - loss: 0.0153 - accuracy: 0.5236
# Epoch 53/100
# 10/10 [==============================] - 6s 573ms/step - loss: 0.0152 - accuracy: 0.5348
# Epoch 54/100
# 10/10 [==============================] - 6s 578ms/step - loss: 0.0153 - accuracy: 0.5347
# Epoch 55/100
# 10/10 [==============================] - 6s 569ms/step - loss: 0.0152 - accuracy: 0.5348
# Epoch 56/100
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0153 - accuracy: 0.5417
# Epoch 57/100
# 10/10 [==============================] - 6s 570ms/step - loss: 0.0153 - accuracy: 0.5409
# Epoch 58/100
# 10/10 [==============================] - 6s 583ms/step - loss: 0.0154 - accuracy: 0.5328
# Epoch 59/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0152 - accuracy: 0.5474
# Epoch 60/100
# 10/10 [==============================] - 6s 579ms/step - loss: 0.0151 - accuracy: 0.5378
# Epoch 61/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0153 - accuracy: 0.5257
# Epoch 62/100
# 10/10 [==============================] - 6s 576ms/step - loss: 0.0153 - accuracy: 0.5219
# Epoch 63/100
# 10/10 [==============================] - 6s 588ms/step - loss: 0.0151 - accuracy: 0.5603
# Epoch 64/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0150 - accuracy: 0.5406
# Epoch 65/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.0151 - accuracy: 0.5456
# Epoch 66/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0151 - accuracy: 0.5482
# Epoch 67/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.0150 - accuracy: 0.5405
# Epoch 68/100
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0151 - accuracy: 0.5314
# Epoch 69/100
# 10/10 [==============================] - 6s 585ms/step - loss: 0.0151 - accuracy: 0.5486
# Epoch 70/100
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0150 - accuracy: 0.5367
# Epoch 71/100
# 10/10 [==============================] - 6s 573ms/step - loss: 0.0150 - accuracy: 0.5414
# Epoch 72/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0151 - accuracy: 0.5515
# Epoch 73/100
# 10/10 [==============================] - 6s 582ms/step - loss: 0.0151 - accuracy: 0.5472
# Epoch 74/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0151 - accuracy: 0.5421
# Epoch 75/100
# 10/10 [==============================] - 6s 573ms/step - loss: 0.0149 - accuracy: 0.5452
# Epoch 76/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0150 - accuracy: 0.5414
# Epoch 77/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.0149 - accuracy: 0.5388
# Epoch 78/100
# 10/10 [==============================] - 6s 572ms/step - loss: 0.0149 - accuracy: 0.5548
# Epoch 79/100
# 10/10 [==============================] - 6s 576ms/step - loss: 0.0151 - accuracy: 0.5441
# Epoch 80/100
# 10/10 [==============================] - 6s 584ms/step - loss: 0.0149 - accuracy: 0.5356
# Epoch 81/100
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0151 - accuracy: 0.5489
# Epoch 82/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0153 - accuracy: 0.5411
# Epoch 83/100
# 10/10 [==============================] - 6s 573ms/step - loss: 0.0152 - accuracy: 0.5603
# Epoch 84/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.0150 - accuracy: 0.5391
# Epoch 85/100
# 10/10 [==============================] - 6s 578ms/step - loss: 0.0150 - accuracy: 0.5361
# Epoch 86/100
# 10/10 [==============================] - 6s 584ms/step - loss: 0.0150 - accuracy: 0.5533
# Epoch 87/100
# 10/10 [==============================] - 6s 583ms/step - loss: 0.0150 - accuracy: 0.5423
# Epoch 88/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.0149 - accuracy: 0.5425
# Epoch 89/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.0149 - accuracy: 0.5506
# Epoch 90/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.0149 - accuracy: 0.5573
# Epoch 91/100
# 10/10 [==============================] - 6s 587ms/step - loss: 0.0149 - accuracy: 0.5461
# Epoch 92/100
# 10/10 [==============================] - 6s 573ms/step - loss: 0.0148 - accuracy: 0.5468
# Epoch 93/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.0148 - accuracy: 0.5544
# Epoch 94/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.0151 - accuracy: 0.5505
# Epoch 95/100
# 10/10 [==============================] - 6s 578ms/step - loss: 0.0149 - accuracy: 0.5637
# Epoch 96/100
# 10/10 [==============================] - 6s 576ms/step - loss: 0.0150 - accuracy: 0.5526
# Epoch 97/100
# 10/10 [==============================] - 6s 578ms/step - loss: 0.0151 - accuracy: 0.5467
# Epoch 98/100
# 10/10 [==============================] - 6s 571ms/step - loss: 0.0148 - accuracy: 0.5629
# Epoch 99/100
# 10/10 [==============================] - 6s 583ms/step - loss: 0.0149 - accuracy: 0.5612
# Epoch 100/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0149 - accuracy: 0.5391

# %%
y = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 69ms/step

# %%
for i in range(10):
  plt.figure(figsize=(10,10))
  or_image = plt.subplot(3,3,1)
  or_image.set_title('Grayscale Input', fontsize=16)
  plt.imshow(X_test[i].reshape((256,256)) , cmap='gray' )

  in_image = plt.subplot(3,3,2)    
  image = Image.fromarray( ( y[i] * 255 ).astype( 'uint8' ) ).resize( ( 1024 , 1024 ) )
  image = np.asarray( image )
  in_image.set_title('Colorized Output', fontsize=16)
  plt.imshow( image )

  ou_image = plt.subplot(3,3,3)
  image = Image.fromarray( ( y_test[i] * 255 ).astype( 'uint8' ) ).resize( ( 1024 , 1024 ) )
  ou_image.set_title('Ground Truth', fontsize=16)
  plt.imshow( image )

  plt.show()
